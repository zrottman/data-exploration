# %% [markdown]
# # Parsing Retrosheet Event Files
#
# There are more questions I have about trends in homerun statistics that unfortunately can't be answered by the Baseball Databank datasets. Instead, I want to turn to the far more detailed Retrosheet datasets, so that I can answer more specific questions. For example, people are always talking about Coors Field in Denver as being a scary place for pitchers--something about the high altitude and/or shape of the stadium as making it especially homerun-prone. Is it true?
#
# To answer this kind of question, the simple offensive statlines provided by the Baseball Databank datasets simply aren't enough. What we really need are the Retrosheet event files, which preserve historical baseball games inning by inning and, in some cases, pitch by pitch.
#
# The problem is that they're not formatted in a way that can immediately be used but need to be parsed. (<a href="https://www.retrosheet.org/eventfile.htm">Here's</a> some info on how these event files are structured.)
#
# So, as a preliminary step, I need to build some parsing functions that can help us deal with Retrosheet's huge amounts of information.
#
# Let me show you what I mean.
#
# I started by downloading event file datasets for 2010–2021, which look like this:

# %%
ls ../data/retrosheet/reg_season/
# Out:
# 2010ANA.EVA  2014ATL.EVN  2018BOS.EVA  ANA2016.ROS  DET2018.ROS  PHI2020.ROS
# 2010ARI.EVN  2014BAL.EVA  2018CHA.EVA  ANA2017.ROS  DET2019.ROS  PHI2021.ROS
# 2010ATL.EVN  2014BOS.EVA  2018CHN.EVN  ANA2018.ROS  DET2020.ROS  PIT2010.ROS
# 2010BAL.EVA  2014CHA.EVA  2018CIN.EVN  ANA2019.ROS  DET2021.ROS  PIT2011.ROS
# 2010BOS.EVA  2014CHN.EVN  2018CLE.EVA  ANA2020.ROS  FLO2010.ROS  PIT2012.ROS
# 2010CHA.EVA  2014CIN.EVN  2018COL.EVN  ANA2021.ROS  FLO2011.ROS  PIT2013.ROS
# 2010CHN.EVN  2014CLE.EVA  2018DET.EVA  ARI2010.ROS  HOU2010.ROS  PIT2014.ROS
# 2010CIN.EVN  2014COL.EVN  2018HOU.EVA  ARI2011.ROS  HOU2011.ROS  PIT2015.ROS
# 2010CLE.EVA  2014DET.EVA  2018KCA.EVA  ARI2012.ROS  HOU2012.ROS  PIT2016.ROS
# 2010COL.EVN  2014HOU.EVA  2018LAN.EVN  ARI2013.ROS  HOU2013.ROS  PIT2017.ROS
# 2010DET.EVA  2014KCA.EVA  2018MIA.EVN  ARI2014.ROS  HOU2014.ROS  PIT2018.ROS
# 2010FLO.EVN  2014LAN.EVN  2018MIL.EVN  ARI2015.ROS  HOU2015.ROS  PIT2019.ROS
# 2010HOU.EVN  2014MIA.EVN  2018MIN.EVA  ARI2016.ROS  HOU2016.ROS  PIT2020.ROS
# 2010KCA.EVA  2014MIL.EVN  2018NYA.EVA  ARI2017.ROS  HOU2017.ROS  PIT2021.ROS
# 2010LAN.EVN  2014MIN.EVA  2018NYN.EVN  ARI2018.ROS  HOU2018.ROS  SDN2010.ROS
# 2010MIL.EVN  2014NYA.EVA  2018OAK.EVA  ARI2019.ROS  HOU2019.ROS  SDN2011.ROS
# 2010MIN.EVA  2014NYN.EVN  2018PHI.EVN  ARI2020.ROS  HOU2020.ROS  SDN2012.ROS
# 2010NYA.EVA  2014OAK.EVA  2018PIT.EVN  ARI2021.ROS  HOU2021.ROS  SDN2013.ROS
# 2010NYN.EVN  2014PHI.EVN  2018SDN.EVN  ATL2010.ROS  KCA2010.ROS  SDN2014.ROS
# 2010OAK.EVA  2014PIT.EVN  2018SEA.EVA  ATL2011.ROS  KCA2011.ROS  SDN2015.ROS
# 2010PHI.EVN  2014SDN.EVN  2018SFN.EVN  ATL2012.ROS  KCA2012.ROS  SDN2016.ROS
# 2010PIT.EVN  2014SEA.EVA  2018SLN.EVN  ATL2013.ROS  KCA2013.ROS  SDN2017.ROS
# 2010SDN.EVN  2014SFN.EVN  2018TBA.EVA  ATL2014.ROS  KCA2014.ROS  SDN2018.ROS
# 2010SEA.EVA  2014SLN.EVN  2018TEX.EVA  ATL2015.ROS  KCA2015.ROS  SDN2019.ROS
# 2010SFN.EVN  2014TBA.EVA  2018TOR.EVA  ATL2016.ROS  KCA2016.ROS  SDN2020.ROS
# 2010SLN.EVN  2014TEX.EVA  2018WAS.EVN  ATL2017.ROS  KCA2017.ROS  SDN2021.ROS
# 2010TBA.EVA  2014TOR.EVA  2019ANA.EVA  ATL2018.ROS  KCA2018.ROS  SEA2010.ROS
# 2010TEX.EVA  2014WAS.EVN  2019ARI.EVN  ATL2019.ROS  KCA2019.ROS  SEA2011.ROS
# 2010TOR.EVA  2015ANA.EVA  2019ATL.EVN  ATL2020.ROS  KCA2020.ROS  SEA2012.ROS
# 2010WAS.EVN  2015ARI.EVN  2019BAL.EVA  ATL2021.ROS  KCA2021.ROS  SEA2013.ROS
# 2011ANA.EVA  2015ATL.EVN  2019BOS.EVA  BAL2010.ROS  LAN2010.ROS  SEA2014.ROS
# 2011ARI.EVN  2015BAL.EVA  2019CHA.EVA  BAL2011.ROS  LAN2011.ROS  SEA2015.ROS
# 2011ATL.EVN  2015BOS.EVA  2019CHN.EVN  BAL2012.ROS  LAN2012.ROS  SEA2016.ROS
# 2011BAL.EVA  2015CHA.EVA  2019CIN.EVN  BAL2013.ROS  LAN2013.ROS  SEA2017.ROS
# 2011BOS.EVA  2015CHN.EVN  2019CLE.EVA  BAL2014.ROS  LAN2014.ROS  SEA2018.ROS
# 2011CHA.EVA  2015CIN.EVN  2019COL.EVN  BAL2015.ROS  LAN2015.ROS  SEA2019.ROS
# 2011CHN.EVN  2015CLE.EVA  2019DET.EVA  BAL2016.ROS  LAN2016.ROS  SEA2020.ROS
# 2011CIN.EVN  2015COL.EVN  2019HOU.EVA  BAL2017.ROS  LAN2017.ROS  SEA2021.ROS
# 2011CLE.EVA  2015DET.EVA  2019KCA.EVA  BAL2018.ROS  LAN2018.ROS  SFN2010.ROS
# 2011COL.EVN  2015HOU.EVA  2019LAN.EVN  BAL2019.ROS  LAN2019.ROS  SFN2011.ROS
# 2011DET.EVA  2015KCA.EVA  2019MIA.EVN  BAL2020.ROS  LAN2020.ROS  SFN2012.ROS
# 2011FLO.EVN  2015LAN.EVN  2019MIL.EVN  BAL2021.ROS  LAN2021.ROS  SFN2013.ROS
# 2011HOU.EVN  2015MIA.EVN  2019MIN.EVA  BOS2010.ROS  MIA2012.ROS  SFN2014.ROS
# 2011KCA.EVA  2015MIL.EVN  2019NYA.EVA  BOS2011.ROS  MIA2013.ROS  SFN2015.ROS
# 2011LAN.EVN  2015MIN.EVA  2019NYN.EVN  BOS2012.ROS  MIA2014.ROS  SFN2016.ROS
# 2011MIL.EVN  2015NYA.EVA  2019OAK.EVA  BOS2013.ROS  MIA2015.ROS  SFN2017.ROS
# 2011MIN.EVA  2015NYN.EVN  2019PHI.EVN  BOS2014.ROS  MIA2016.ROS  SFN2018.ROS
# 2011NYA.EVA  2015OAK.EVA  2019PIT.EVN  BOS2015.ROS  MIA2017.ROS  SFN2019.ROS
# 2011NYN.EVN  2015PHI.EVN  2019SDN.EVN  BOS2016.ROS  MIA2018.ROS  SFN2020.ROS
# 2011OAK.EVA  2015PIT.EVN  2019SEA.EVA  BOS2017.ROS  MIA2019.ROS  SFN2021.ROS
# 2011PHI.EVN  2015SDN.EVN  2019SFN.EVN  BOS2018.ROS  MIA2020.ROS  SLN2010.ROS
# 2011PIT.EVN  2015SEA.EVA  2019SLN.EVN  BOS2019.ROS  MIA2021.ROS  SLN2011.ROS
# 2011SDN.EVN  2015SFN.EVN  2019TBA.EVA  BOS2020.ROS  MIL2010.ROS  SLN2012.ROS
# 2011SEA.EVA  2015SLN.EVN  2019TEX.EVA  BOS2021.ROS  MIL2011.ROS  SLN2013.ROS
# 2011SFN.EVN  2015TBA.EVA  2019TOR.EVA  CHA2010.ROS  MIL2012.ROS  SLN2014.ROS
# 2011SLN.EVN  2015TEX.EVA  2019WAS.EVN  CHA2011.ROS  MIL2013.ROS  SLN2015.ROS
# 2011TBA.EVA  2015TOR.EVA  2020ANA.EVA  CHA2012.ROS  MIL2014.ROS  SLN2016.ROS
# 2011TEX.EVA  2015WAS.EVN  2020ARI.EVN  CHA2013.ROS  MIL2015.ROS  SLN2017.ROS
# 2011TOR.EVA  2016ANA.EVA  2020ATL.EVN  CHA2014.ROS  MIL2016.ROS  SLN2018.ROS
# 2011WAS.EVN  2016ARI.EVN  2020BAL.EVA  CHA2015.ROS  MIL2017.ROS  SLN2019.ROS
# 2012ANA.EVA  2016ATL.EVN  2020BOS.EVA  CHA2016.ROS  MIL2018.ROS  SLN2020.ROS
# 2012ARI.EVN  2016BAL.EVA  2020CHA.EVA  CHA2017.ROS  MIL2019.ROS  SLN2021.ROS
# 2012ATL.EVN  2016BOS.EVA  2020CHN.EVN  CHA2018.ROS  MIL2020.ROS  TBA2010.ROS
# 2012BAL.EVA  2016CHA.EVA  2020CIN.EVN  CHA2019.ROS  MIL2021.ROS  TBA2011.ROS
# 2012BOS.EVA  2016CHN.EVN  2020CLE.EVA  CHA2020.ROS  MIN2010.ROS  TBA2012.ROS
# 2012CHA.EVA  2016CIN.EVN  2020COL.EVN  CHA2021.ROS  MIN2011.ROS  TBA2013.ROS
# 2012CHN.EVN  2016CLE.EVA  2020DET.EVA  CHN2010.ROS  MIN2012.ROS  TBA2014.ROS
# 2012CIN.EVN  2016COL.EVN  2020HOU.EVA  CHN2011.ROS  MIN2013.ROS  TBA2015.ROS
# 2012CLE.EVA  2016DET.EVA  2020KCA.EVA  CHN2012.ROS  MIN2014.ROS  TBA2016.ROS
# 2012COL.EVN  2016HOU.EVA  2020LAN.EVN  CHN2013.ROS  MIN2015.ROS  TBA2017.ROS
# 2012DET.EVA  2016KCA.EVA  2020MIA.EVN  CHN2014.ROS  MIN2016.ROS  TBA2018.ROS
# 2012HOU.EVN  2016LAN.EVN  2020MIL.EVN  CHN2015.ROS  MIN2017.ROS  TBA2019.ROS
# 2012KCA.EVA  2016MIA.EVN  2020MIN.EVA  CHN2016.ROS  MIN2018.ROS  TBA2020.ROS
# 2012LAN.EVN  2016MIL.EVN  2020NYA.EVA  CHN2017.ROS  MIN2019.ROS  TBA2021.ROS
# 2012MIA.EVN  2016MIN.EVA  2020NYN.EVN  CHN2018.ROS  MIN2020.ROS  TEAM2010
# 2012MIL.EVN  2016NYA.EVA  2020OAK.EVA  CHN2019.ROS  MIN2021.ROS  TEAM2011
# 2012MIN.EVA  2016NYN.EVN  2020PHI.EVN  CHN2020.ROS  NYA2010.ROS  TEAM2012
# 2012NYA.EVA  2016OAK.EVA  2020PIT.EVN  CHN2021.ROS  NYA2011.ROS  TEAM2013
# 2012NYN.EVN  2016PHI.EVN  2020SDN.EVN  CIN2010.ROS  NYA2012.ROS  TEAM2014
# 2012OAK.EVA  2016PIT.EVN  2020SEA.EVA  CIN2011.ROS  NYA2013.ROS  TEAM2015
# 2012PHI.EVN  2016SDN.EVN  2020SFN.EVN  CIN2012.ROS  NYA2014.ROS  TEAM2016
# 2012PIT.EVN  2016SEA.EVA  2020SLN.EVN  CIN2013.ROS  NYA2015.ROS  TEAM2017
# 2012SDN.EVN  2016SFN.EVN  2020TBA.EVA  CIN2014.ROS  NYA2016.ROS  TEAM2018
# 2012SEA.EVA  2016SLN.EVN  2020TEX.EVA  CIN2015.ROS  NYA2017.ROS  TEAM2019
# 2012SFN.EVN  2016TBA.EVA  2020TOR.EVA  CIN2016.ROS  NYA2018.ROS  TEAM2020
# 2012SLN.EVN  2016TEX.EVA  2020WAS.EVN  CIN2017.ROS  NYA2019.ROS  TEAM2021
# 2012TBA.EVA  2016TOR.EVA  2021ANA.EVA  CIN2018.ROS  NYA2020.ROS  TEX2010.ROS
# 2012TEX.EVA  2016WAS.EVN  2021ARI.EVN  CIN2019.ROS  NYA2021.ROS  TEX2011.ROS
# 2012TOR.EVA  2017ANA.EVA  2021ATL.EVN  CIN2020.ROS  NYN2010.ROS  TEX2012.ROS
# 2012WAS.EVN  2017ARI.EVN  2021BAL.EVA  CIN2021.ROS  NYN2011.ROS  TEX2013.ROS
# 2013ANA.EVA  2017ATL.EVN  2021BOS.EVA  CLE2010.ROS  NYN2012.ROS  TEX2014.ROS
# 2013ARI.EVN  2017BAL.EVA  2021CHA.EVA  CLE2011.ROS  NYN2013.ROS  TEX2015.ROS
# 2013ATL.EVN  2017BOS.EVA  2021CHN.EVN  CLE2012.ROS  NYN2014.ROS  TEX2016.ROS
# 2013BAL.EVA  2017CHA.EVA  2021CIN.EVN  CLE2013.ROS  NYN2015.ROS  TEX2017.ROS
# 2013BOS.EVA  2017CHN.EVN  2021CLE.EVA  CLE2014.ROS  NYN2016.ROS  TEX2018.ROS
# 2013CHA.EVA  2017CIN.EVN  2021COL.EVN  CLE2015.ROS  NYN2017.ROS  TEX2019.ROS
# 2013CHN.EVN  2017CLE.EVA  2021DET.EVA  CLE2016.ROS  NYN2018.ROS  TEX2020.ROS
# 2013CIN.EVN  2017COL.EVN  2021HOU.EVA  CLE2017.ROS  NYN2019.ROS  TEX2021.ROS
# 2013CLE.EVA  2017DET.EVA  2021KCA.EVA  CLE2018.ROS  NYN2020.ROS  TOR2010.ROS
# 2013COL.EVN  2017HOU.EVA  2021LAN.EVN  CLE2019.ROS  NYN2021.ROS  TOR2011.ROS
# 2013DET.EVA  2017KCA.EVA  2021MIA.EVN  CLE2020.ROS  OAK2010.ROS  TOR2012.ROS
# 2013HOU.EVA  2017LAN.EVN  2021MIL.EVN  CLE2021.ROS  OAK2011.ROS  TOR2013.ROS
# 2013KCA.EVA  2017MIA.EVN  2021MIN.EVA  COL2010.ROS  OAK2012.ROS  TOR2014.ROS
# 2013LAN.EVN  2017MIL.EVN  2021NYA.EVA  COL2011.ROS  OAK2013.ROS  TOR2015.ROS
# 2013MIA.EVN  2017MIN.EVA  2021NYN.EVN  COL2012.ROS  OAK2014.ROS  TOR2016.ROS
# 2013MIL.EVN  2017NYA.EVA  2021OAK.EVA  COL2013.ROS  OAK2015.ROS  TOR2017.ROS
# 2013MIN.EVA  2017NYN.EVN  2021PHI.EVN  COL2014.ROS  OAK2016.ROS  TOR2018.ROS
# 2013NYA.EVA  2017OAK.EVA  2021PIT.EVN  COL2015.ROS  OAK2017.ROS  TOR2019.ROS
# 2013NYN.EVN  2017PHI.EVN  2021SDN.EVN  COL2016.ROS  OAK2018.ROS  TOR2020.ROS
# 2013OAK.EVA  2017PIT.EVN  2021SEA.EVA  COL2017.ROS  OAK2019.ROS  TOR2021.ROS
# 2013PHI.EVN  2017SDN.EVN  2021SFN.EVN  COL2018.ROS  OAK2020.ROS  WAS2010.ROS
# 2013PIT.EVN  2017SEA.EVA  2021SLN.EVN  COL2019.ROS  OAK2021.ROS  WAS2011.ROS
# 2013SDN.EVN  2017SFN.EVN  2021TBA.EVA  COL2020.ROS  PHI2010.ROS  WAS2012.ROS
# 2013SEA.EVA  2017SLN.EVN  2021TEX.EVA  COL2021.ROS  PHI2011.ROS  WAS2013.ROS
# 2013SFN.EVN  2017TBA.EVA  2021TOR.EVA  DET2010.ROS  PHI2012.ROS  WAS2014.ROS
# 2013SLN.EVN  2017TEX.EVA  2021WAS.EVN  DET2011.ROS  PHI2013.ROS  WAS2015.ROS
# 2013TBA.EVA  2017TOR.EVA  ANA2010.ROS  DET2012.ROS  PHI2014.ROS  WAS2016.ROS
# 2013TEX.EVA  2017WAS.EVN  ANA2011.ROS  DET2013.ROS  PHI2015.ROS  WAS2017.ROS
# 2013TOR.EVA  2018ANA.EVA  ANA2012.ROS  DET2014.ROS  PHI2016.ROS  WAS2018.ROS
# 2013WAS.EVN  2018ARI.EVN  ANA2013.ROS  DET2015.ROS  PHI2017.ROS  WAS2019.ROS
# 2014ANA.EVA  2018ATL.EVN  ANA2014.ROS  DET2016.ROS  PHI2018.ROS  WAS2020.ROS
# 2014ARI.EVN  2018BAL.EVA  ANA2015.ROS  DET2017.ROS  PHI2019.ROS  WAS2021.ROS

# %% [markdown]
# There's two types of datasets here:
# <ul>
#     <li> Event files are prefixed by the year and then the home team to which they pertain, appended by EVA or EVN depending on whether it's an American League or National League team</li>
#     <li> Roster files are appended by .ROS, and these just contain roster info for the entire season—not relevant for us now</li>
# </ul>
#
# Here's what one of these event files looks like:

# %%
# !head -n 50 ../data/retrosheet/reg_season/2017LAN.EVN
# Out:
# id,LAN201704030
# version,2
# info,visteam,SDN
# info,hometeam,LAN
# info,site,LOS03
# info,date,2017/04/03
# info,number,0
# info,starttime,1:10PM
# info,daynight,day
# info,usedh,false
# info,umphome,vanol901
# info,ump1b,marqa901
# info,ump2b,fairc901
# info,ump3b,rackd901
# info,howscored,park
# info,pitches,pitches
# info,oscorer,whitj701
# info,temp,67
# info,winddir,torf
# info,windspeed,3
# info,fieldcond,unknown
# info,precip,unknown
# info,sky,sunny
# info,timeofgame,172
# info,attendance,53701
# info,wp,kersc001
# info,lp,chacj001
# info,save,
# start,margm001,"Manuel Margot",0,1,8
# start,myerw001,"Wil Myers",0,2,3
# start,solay001,"Yangervis Solarte",0,3,4
# start,renfh001,"Hunter Renfroe",0,4,9
# start,schir001,"Ryan Schimpf",0,5,5
# start,hedga001,"Austin Hedges",0,6,2
# start,aybae001,"Erick Aybar",0,7,6
# start,chacj001,"Jhoulys Chacin",0,8,1
# start,jankt001,"Travis Jankowski",0,9,7
# start,tolea001,"Andrew Toles",1,1,7
# start,seagc001,"Corey Seager",1,2,6
# start,turnj001,"Justin Turner",1,3,5
# start,gonza003,"Adrian Gonzalez",1,4,3
# start,forsl001,"Logan Forsythe",1,5,4
# start,pedej001,"Joc Pederson",1,6,8
# start,grany001,"Yasmani Grandal",1,7,2
# start,puigy001,"Yasiel Puig",1,8,9
# start,kersc001,"Clayton Kershaw",1,9,1
# play,1,0,margm001,12,CFBS,K
# play,1,0,myerw001,12,BSSX,E6/TH/G+.B-2
# play,1,0,solay001,00,B,WP.2-3
# play,1,0,solay001,22,B.*BFFX,S7/G.3-H(UR)

# %% [markdown]
# There are different kinds of records here, identified by the term that prepending each row.
# <ul>
#     <li>The <code>id</code> record at the top is a unique identifer for each game</li>
#     <li>The <code>info</code> records pertain to game-specific data, such as the home team, visiting team, attendance, etc.</li>
#     <li>The <code>start</code> records specify the players who are starting for both teams</li>
#     <li>the <code>play</code> records specify individual plays</li>
# </ul>
# And then there are a number of other record types that we don't see in this snippet here.
#
# For a simple place to start, I decided to write some routines that will parse the <code>id</code> and <code>info</code> record types. This won't allow us to answer my question about Coors Field, but it's a first step in figuring out how to make these datasets useable.
#
# In the <code>retrosheet_utils</code> module I'll import below, I've written two functions thus far:
# <ul>
#     <li><code>parse_event_file_info()</code> takes a path to a sepcific event file and returns a list of dictionaries, each of which contains <code>info</code> fields for a given game <code>id</code></li>
#     <li><code>load_season_info()</code> takes a year and runs <code>parse_event_file_info()</code> for each event file pertaining to that year, returning a list of dictionaries of all the games of that year</li>
#     </ul>
#
# Here's what it looks like:

# %%
import retrosheet_utils

data = retrosheet_utils.load_season_info(2017)

data
# Out:
# [{'id': 'BOS201704030',
#   'visteam': 'PIT',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/03',
#   'number': '0',
#   'starttime': '2:06PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'demud901',
#   'ump1b': 'nauep901',
#   'ump2b': 'guccc901',
#   'ump3b': 'torrc901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '48',
#   'winddir': 'fromrf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '183',
#   'attendance': '36594',
#   'wp': 'porcr001',
#   'lp': 'coleg001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201704050',
#   'visteam': 'PIT',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/05',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'nauep901',
#   'ump1b': 'guccc901',
#   'ump2b': 'torrc901',
#   'ump3b': 'demud901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '40',
#   'winddir': 'fromrf',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '233',
#   'attendance': '36137',
#   'wp': 'kellj001',
#   'lp': 'basta001',
#   'save': None},
#  {'id': 'BOS201704110',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/11',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'coope901',
#   'ump1b': 'johna901',
#   'ump2b': 'morag901',
#   'ump3b': 'cedeg901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '74',
#   'winddir': 'tolf',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '195',
#   'attendance': '37497',
#   'wp': 'pomed001',
#   'lp': 'bundd001',
#   'save': None},
#  {'id': 'BOS201704120',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/12',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'johna901',
#   'ump1b': 'morag901',
#   'ump2b': 'cedeg901',
#   'ump3b': 'coope901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '51',
#   'winddir': 'rtol',
#   'windspeed': '6',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '226',
#   'attendance': '32211',
#   'wp': 'givem001',
#   'lp': 'wrigs001',
#   'save': None},
#  {'id': 'BOS201704130',
#   'visteam': 'PIT',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/13',
#   'number': '0',
#   'starttime': '2:06PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'morag901',
#   'ump1b': 'cedeg901',
#   'ump2b': 'coope901',
#   'ump3b': 'johna901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '53',
#   'winddir': 'torf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '195',
#   'attendance': '32400',
#   'wp': 'barnm001',
#   'lp': 'nicaj001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201704140',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/14',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'barkl901',
#   'ump1b': 'tumpj901',
#   'ump2b': 'barrt901',
#   'ump3b': 'herna901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '53',
#   'winddir': 'fromrf',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '217',
#   'attendance': '36813',
#   'wp': 'archc001',
#   'lp': 'porcr001',
#   'save': None},
#  {'id': 'BOS201704150',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/15',
#   'number': '0',
#   'starttime': '4:06PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'tumpj901',
#   'ump1b': 'barrt901',
#   'ump2b': 'herna901',
#   'ump3b': 'barkl901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '69',
#   'winddir': 'tocf',
#   'windspeed': '23',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '174',
#   'attendance': '36686',
#   'wp': 'salec001',
#   'lp': 'huntt002',
#   'save': 'kimbc001'},
#  {'id': 'BOS201704160',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/16',
#   'number': '0',
#   'starttime': '1:35PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'barrt901',
#   'ump1b': 'herna901',
#   'ump2b': 'barkl901',
#   'ump3b': 'tumpj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '85',
#   'winddir': 'torf',
#   'windspeed': '23',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '226',
#   'attendance': '36209',
#   'wp': 'kellj001',
#   'lp': 'farqd001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201704170',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/17',
#   'number': '0',
#   'starttime': '11:06AM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'herna901',
#   'ump1b': 'barkl901',
#   'ump2b': 'tumpj901',
#   'ump3b': 'barrt901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '70',
#   'winddir': 'torf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '187',
#   'attendance': '37318',
#   'wp': 'wrigs001',
#   'lp': 'snelb001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201704260',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/26',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'culbf901',
#   'ump1b': 'carlm901',
#   'ump2b': 'gonzm901',
#   'ump3b': 'barkl901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '53',
#   'winddir': 'fromcf',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '196',
#   'attendance': '32072',
#   'wp': 'sevel001',
#   'lp': 'porcr001',
#   'save': 'chapa001'},
#  {'id': 'BOS201704270',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/27',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'carlm901',
#   'ump1b': 'gonzm901',
#   'ump2b': 'barkl901',
#   'ump3b': 'culbf901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '53',
#   'winddir': 'fromrf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '141',
#   'attendance': '34054',
#   'wp': 'tanam001',
#   'lp': 'salec001',
#   'save': None},
#  {'id': 'BOS201704280',
#   'visteam': 'CHN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/28',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'everm901',
#   'ump1b': 'welkb901',
#   'ump2b': 'drecb901',
#   'ump3b': 'bakej902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '81',
#   'winddir': 'tocf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '208',
#   'attendance': '37054',
#   'wp': 'pomed001',
#   'lp': 'arrij001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201704290',
#   'visteam': 'CHN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/29',
#   'number': '0',
#   'starttime': '4:05PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'welkb901',
#   'ump1b': 'drecb901',
#   'ump2b': 'bakej902',
#   'ump3b': 'everm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '83',
#   'winddir': 'torf',
#   'windspeed': '20',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '180',
#   'attendance': '36776',
#   'wp': 'lackj001',
#   'lp': 'wrigs001',
#   'save': 'daviw001'},
#  {'id': 'BOS201704300',
#   'visteam': 'CHN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/04/30',
#   'number': '0',
#   'starttime': '8:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'drecb901',
#   'ump1b': 'bakej902',
#   'ump2b': 'everm901',
#   'ump3b': 'welkb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '47',
#   'winddir': 'rtol',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '208',
#   'attendance': '36916',
#   'wp': 'barnm001',
#   'lp': 'uehak001',
#   'save': None},
#  {'id': 'BOS201705010',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/01',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'gibsg901',
#   'ump1b': 'reybd901',
#   'ump2b': 'holbs901',
#   'ump3b': 'wolfj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '47',
#   'winddir': 'fromcf',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '190',
#   'attendance': '33489',
#   'wp': 'bundd001',
#   'lp': 'porcr001',
#   'save': 'bracb001'},
#  {'id': 'BOS201705020',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/02',
#   'number': '0',
#   'starttime': '7:09PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'reybd901',
#   'ump1b': 'holbs901',
#   'ump2b': 'wolfj901',
#   'ump3b': 'gibsg901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '63',
#   'winddir': 'tocf',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '153',
#   'attendance': '32932',
#   'wp': 'salec001',
#   'lp': 'ashea001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201705030',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/03',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'holbs901',
#   'ump1b': 'wolfj901',
#   'ump2b': 'gibsg901',
#   'ump3b': 'reybd901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '57',
#   'winddir': 'torf',
#   'windspeed': '18',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '204',
#   'attendance': '33162',
#   'wp': 'pomed001',
#   'lp': 'gausk001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201705040',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/04',
#   'number': '0',
#   'starttime': '7:12PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'wolfj901',
#   'ump1b': 'gibsg901',
#   'ump2b': 'reybd901',
#   'ump3b': 'holbs901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '52',
#   'winddir': 'rtol',
#   'windspeed': '17',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '201',
#   'attendance': '36563',
#   'wp': 'wilst004',
#   'lp': 'kendk001',
#   'save': None},
#  {'id': 'BOS201705120',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/12',
#   'number': '0',
#   'starttime': '7:09PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'blasc901',
#   'ump1b': 'nelsj901',
#   'ump2b': 'diazl901',
#   'ump3b': 'eddid901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '50',
#   'winddir': 'fromrf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '204',
#   'attendance': '36496',
#   'wp': 'cobba001',
#   'lp': 'porcr001',
#   'save': 'coloa001'},
#  {'id': 'BOS201705130',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/13',
#   'number': '0',
#   'starttime': '1:05PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'nelsj901',
#   'ump1b': 'diazl901',
#   'ump2b': 'eddid901',
#   'ump3b': 'blasc901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '51',
#   'winddir': 'fromrf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '174',
#   'attendance': '35447',
#   'wp': 'salec001',
#   'lp': 'snelb001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201705140',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/14',
#   'number': '0',
#   'starttime': '1:35PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'diazl901',
#   'ump1b': 'eddid901',
#   'ump2b': 'blasc901',
#   'ump3b': 'nelsj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '48',
#   'winddir': 'fromlf',
#   'windspeed': '20',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '272',
#   'attendance': '35080',
#   'wp': 'andrm001',
#   'lp': 'pomed001',
#   'save': None},
#  {'id': 'BOS201705230',
#   'visteam': 'TEX',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/23',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'welkb901',
#   'ump1b': 'marqa901',
#   'ump2b': 'fairc901',
#   'ump3b': 'rackd901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '61',
#   'winddir': 'fromrf',
#   'windspeed': '7',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '203',
#   'attendance': '34769',
#   'wp': 'porcr001',
#   'lp': 'casha001',
#   'save': None},
#  {'id': 'BOS201705240',
#   'visteam': 'TEX',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/24',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'marqa901',
#   'ump1b': 'fairc901',
#   'ump2b': 'rackd901',
#   'ump3b': 'welkb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '58',
#   'winddir': 'fromrf',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '179',
#   'attendance': '36089',
#   'wp': 'salec001',
#   'lp': 'dysos001',
#   'save': None},
#  {'id': 'BOS201705250',
#   'visteam': 'TEX',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/25',
#   'number': '0',
#   'starttime': '7:38PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'fairc901',
#   'ump1b': 'rackd901',
#   'ump2b': 'welkb901',
#   'ump3b': 'marqa901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '52',
#   'winddir': 'fromcf',
#   'windspeed': '16',
#   'fieldcond': 'wet',
#   'precip': 'rain',
#   'sky': 'unknown',
#   'timeofgame': '203',
#   'attendance': '33484',
#   'wp': 'pomed001',
#   'lp': 'martn002',
#   'save': None},
#  {'id': 'BOS201705260',
#   'visteam': 'SEA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/26',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'blakr901',
#   'ump1b': 'drecb901',
#   'ump2b': 'everm901',
#   'ump3b': 'bakej902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '59',
#   'winddir': 'torf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '191',
#   'attendance': '35080',
#   'wp': 'rodre004',
#   'lp': 'gally001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201705270',
#   'visteam': 'SEA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/27',
#   'number': '0',
#   'starttime': '4:05PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'drecb901',
#   'ump1b': 'everm901',
#   'ump2b': 'bakej902',
#   'ump3b': 'blakr901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '59',
#   'winddir': 'fromrf',
#   'windspeed': '14',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '143',
#   'attendance': '36985',
#   'wp': 'johnb004',
#   'lp': 'whalr001',
#   'save': None},
#  {'id': 'BOS201705280',
#   'visteam': 'SEA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/05/28',
#   'number': '0',
#   'starttime': '1:36PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'everm901',
#   'ump1b': 'bakej902',
#   'ump2b': 'blakr901',
#   'ump3b': 'drecb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '62',
#   'winddir': 'fromrf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '194',
#   'attendance': '37174',
#   'wp': 'bergc001',
#   'lp': 'porcr001',
#   'save': None},
#  {'id': 'BOS201706090',
#   'visteam': 'DET',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/09',
#   'number': '0',
#   'starttime': '7:09PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'fairc901',
#   'ump1b': 'rackd901',
#   'ump2b': 'marqa901',
#   'ump3b': 'welkb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '71',
#   'winddir': 'tolf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '216',
#   'attendance': '36853',
#   'wp': 'barnm001',
#   'lp': 'wilsa001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201706100',
#   'visteam': 'DET',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/10',
#   'number': '0',
#   'starttime': '7:15PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'rackd901',
#   'ump1b': 'marqa901',
#   'ump2b': 'welkb901',
#   'ump3b': 'fairc901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '78',
#   'winddir': 'tolf',
#   'windspeed': '14',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '219',
#   'attendance': '37162',
#   'wp': 'salec001',
#   'lp': 'saupw001',
#   'save': None},
#  {'id': 'BOS201706110',
#   'visteam': 'DET',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/11',
#   'number': '0',
#   'starttime': '8:08PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'marqa901',
#   'ump1b': 'welkb901',
#   'ump2b': 'fairc901',
#   'ump3b': 'rackd901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '88',
#   'winddir': 'tocf',
#   'windspeed': '17',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '246',
#   'attendance': '35457',
#   'wp': 'norrd002',
#   'lp': 'pomed001',
#   'save': None},
#  {'id': 'BOS201706120',
#   'visteam': 'PHI',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/12',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'barrl901',
#   'ump1b': 'sches901',
#   'ump2b': 'reynj901',
#   'ump3b': 'knigb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '93',
#   'winddir': 'torf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '256',
#   'attendance': '36757',
#   'wp': 'barnm001',
#   'lp': 'fienc001',
#   'save': None},
#  {'id': 'BOS201706130',
#   'visteam': 'PHI',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/13',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'sches901',
#   'ump1b': 'reynj901',
#   'ump2b': 'knigb901',
#   'ump3b': 'barrl901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '79',
#   'winddir': 'tolf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '264',
#   'attendance': '37141',
#   'wp': 'abadf001',
#   'lp': 'garcl005',
#   'save': None},
#  {'id': 'BOS201706230',
#   'visteam': 'ANA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/23',
#   'number': '0',
#   'starttime': '7:16PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'millb901',
#   'ump1b': 'blakr901',
#   'ump2b': 'hamaa901',
#   'ump3b': 'belld901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '78',
#   'winddir': 'tolf',
#   'windspeed': '14',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '187',
#   'attendance': '37034',
#   'wp': 'porcr001',
#   'lp': 'meyea001',
#   'save': None},
#  {'id': 'BOS201706240',
#   'visteam': 'ANA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/24',
#   'number': '0',
#   'starttime': '7:16PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'blakr901',
#   'ump1b': 'hamaa901',
#   'ump2b': 'belld901',
#   'ump3b': 'millb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '84',
#   'winddir': 'torf',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '214',
#   'attendance': '36868',
#   'wp': 'ramij002',
#   'lp': 'pricd001',
#   'save': 'parkb001'},
#  {'id': 'BOS201706250',
#   'visteam': 'ANA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/25',
#   'number': '0',
#   'starttime': '1:35PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'hamaa901',
#   'ump1b': 'belld901',
#   'ump2b': 'millb901',
#   'ump3b': 'blakr901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '80',
#   'winddir': 'tocf',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '170',
#   'attendance': '36474',
#   'wp': 'bridp001',
#   'lp': 'fistd001',
#   'save': 'petiy001'},
#  {'id': 'BOS201706260',
#   'visteam': 'MIN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/26',
#   'number': '0',
#   'starttime': '7:12PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'littw901',
#   'ump1b': 'kellj901',
#   'ump2b': 'timmt901',
#   'ump3b': 'hoyej901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '78',
#   'winddir': 'torf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '175',
#   'attendance': '37172',
#   'wp': 'salec001',
#   'lp': 'berrj001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201706270',
#   'visteam': 'MIN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/27',
#   'number': '0',
#   'starttime': '8:00PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'kellj901',
#   'ump1b': 'hoyej901',
#   'ump2b': 'addir901',
#   'ump3b': 'littw901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '69',
#   'winddir': 'rtol',
#   'windspeed': '22',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '198',
#   'attendance': '36804',
#   'wp': 'pomed001',
#   'lp': 'santh001',
#   'save': None},
#  {'id': 'BOS201706280',
#   'visteam': 'MIN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/28',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'hoyej901',
#   'ump1b': 'addir901',
#   'ump2b': 'littw901',
#   'ump3b': 'kellj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '76',
#   'winddir': 'torf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '194',
#   'attendance': '37487',
#   'wp': 'mejia001',
#   'lp': 'porcr001',
#   'save': 'kintb001'},
#  {'id': 'BOS201706290',
#   'visteam': 'MIN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/06/29',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'addir901',
#   'ump1b': 'littw901',
#   'ump2b': 'kellj901',
#   'ump3b': 'hoyej901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '73',
#   'winddir': 'tolf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'overcast',
#   'timeofgame': '204',
#   'attendance': '37445',
#   'wp': 'pricd001',
#   'lp': 'gibsk002',
#   'save': 'kimbc001'},
#  {'id': 'BOS201707140',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/14',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'coope901',
#   'ump1b': 'cedeg901',
#   'ump2b': 'morag901',
#   'ump3b': 'johna901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '63',
#   'winddir': 'fromrf',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '207',
#   'attendance': '37570',
#   'wp': 'scotr001',
#   'lp': 'chapa001',
#   'save': None},
#  {'id': 'BOS201707150',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/15',
#   'number': '0',
#   'starttime': '4:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'cedeg901',
#   'ump1b': 'morag901',
#   'ump2b': 'johna901',
#   'ump3b': 'coope901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '72',
#   'winddir': 'rtol',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '350',
#   'attendance': '36936',
#   'wp': 'hellb001',
#   'lp': 'fistd001',
#   'save': None},
#  {'id': 'BOS201707161',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/16',
#   'number': '1',
#   'starttime': '1:06PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'morag901',
#   'ump1b': 'dejer901',
#   'ump2b': 'coope901',
#   'ump3b': 'cedeg901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '79',
#   'winddir': 'rtol',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '193',
#   'attendance': '37343',
#   'wp': 'sabac001',
#   'lp': 'porcr001',
#   'save': 'chapa001'},
#  {'id': 'BOS201707162',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/16',
#   'number': '2',
#   'starttime': '8:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'johna901',
#   'ump1b': 'coope901',
#   'ump2b': 'cedeg901',
#   'ump3b': 'dejer901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '76',
#   'winddir': 'rtol',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '179',
#   'attendance': '36719',
#   'wp': 'pricd001',
#   'lp': 'tanam001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201707170',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/17',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'segac901',
#   'ump1b': 'everm901',
#   'ump2b': 'bakej902',
#   'ump3b': 'drecb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '80',
#   'winddir': 'tolf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '198',
#   'attendance': '36144',
#   'wp': 'teper001',
#   'lp': 'hembh001',
#   'save': 'osunr001'},
#  {'id': 'BOS201707180',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/18',
#   'number': '0',
#   'starttime': '8:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'everm901',
#   'ump1b': 'bakej902',
#   'ump2b': 'drecb901',
#   'ump3b': 'segac901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '75',
#   'winddir': 'rtol',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '299',
#   'attendance': '36488',
#   'wp': 'velah001',
#   'lp': 'bolsm001',
#   'save': None},
#  {'id': 'BOS201707190',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/19',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'bakej902',
#   'ump1b': 'drecb901',
#   'ump2b': 'segac901',
#   'ump3b': 'everm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '90',
#   'winddir': 'torf',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '167',
#   'attendance': '37360',
#   'wp': 'pomed001',
#   'lp': 'sanca006',
#   'save': None},
#  {'id': 'BOS201707200',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/20',
#   'number': '0',
#   'starttime': '1:36PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'drecb901',
#   'ump1b': 'segac901',
#   'ump2b': 'everm901',
#   'ump3b': 'bakej902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '88',
#   'winddir': 'torf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '205',
#   'attendance': '37094',
#   'wp': 'leond003',
#   'lp': 'fistd001',
#   'save': 'osunr001'},
#  {'id': 'BOS201707280',
#   'visteam': 'KCA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/28',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'millb901',
#   'ump1b': 'ticht901',
#   'ump2b': 'lentn901',
#   'ump3b': 'hamaa901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '74',
#   'winddir': 'rtol',
#   'windspeed': '7',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '164',
#   'attendance': '37321',
#   'wp': 'vargj001',
#   'lp': 'porcr001',
#   'save': 'herrk001'},
#  {'id': 'BOS201707290',
#   'visteam': 'KCA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/29',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'ticht901',
#   'ump1b': 'lentn901',
#   'ump2b': 'hamaa901',
#   'ump3b': 'millb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '66',
#   'winddir': 'fromcf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '285',
#   'attendance': '36912',
#   'wp': 'barnm001',
#   'lp': 'minom001',
#   'save': None},
#  {'id': 'BOS201707300',
#   'visteam': 'KCA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/30',
#   'number': '0',
#   'starttime': '1:38PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'lentn901',
#   'ump1b': 'hamaa901',
#   'ump2b': 'millb901',
#   'ump3b': 'ticht901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '72',
#   'winddir': 'fromcf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '193',
#   'attendance': '36480',
#   'wp': 'hammj002',
#   'lp': 'barnm001',
#   'save': 'herrk001'},
#  {'id': 'BOS201707310',
#   'visteam': 'CLE',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/07/31',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'wegnm901',
#   'ump1b': 'fostm901',
#   'ump2b': 'muchm901',
#   'ump3b': 'blakr901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '77',
#   'winddir': 'rtol',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '167',
#   'attendance': '37169',
#   'wp': 'fistd001',
#   'lp': 'clevm001',
#   'save': None},
#  {'id': 'BOS201708010',
#   'visteam': 'CLE',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/01',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'fostm901',
#   'ump1b': 'muchm901',
#   'ump2b': 'blakr901',
#   'ump3b': 'wegnm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '83',
#   'winddir': 'fromrf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '216',
#   'attendance': '37126',
#   'wp': 'kimbc001',
#   'lp': 'allec002',
#   'save': None},
#  {'id': 'BOS201708030',
#   'visteam': 'CHA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/03',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'laynj901',
#   'ump1b': 'hudsm901',
#   'ump2b': 'estam901',
#   'ump3b': 'belld901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '79',
#   'winddir': 'tolf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '206',
#   'attendance': '37442',
#   'wp': 'porcr001',
#   'lp': 'gonzm003',
#   'save': None},
#  {'id': 'BOS201708040',
#   'visteam': 'CHA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/04',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'hudsm901',
#   'ump1b': 'estam901',
#   'ump2b': 'belld901',
#   'ump3b': 'laynj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '80',
#   'winddir': 'tolf',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '223',
#   'attendance': '36612',
#   'wp': 'hembh001',
#   'lp': 'bumma001',
#   'save': None},
#  {'id': 'BOS201708050',
#   'visteam': 'CHA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/05',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'estam901',
#   'ump1b': 'belld901',
#   'ump2b': 'laynj901',
#   'ump3b': 'hudsm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '75',
#   'winddir': 'tolf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '161',
#   'attendance': '36599',
#   'wp': 'pomed001',
#   'lp': 'shiej002',
#   'save': 'kimbc001'},
#  {'id': 'BOS201708060',
#   'visteam': 'CHA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/06',
#   'number': '0',
#   'starttime': '1:36PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'belld901',
#   'ump1b': 'laynj901',
#   'ump2b': 'hudsm901',
#   'ump3b': 'estam901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '74',
#   'winddir': 'torf',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '156',
#   'attendance': '37283',
#   'wp': 'fistd001',
#   'lp': 'pelfm001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201708140',
#   'visteam': 'CLE',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/14',
#   'number': '0',
#   'starttime': '6:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'hallt901',
#   'ump1b': 'carav901',
#   'ump2b': 'segac901',
#   'ump3b': 'rippm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '72',
#   'winddir': 'fromrf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '194',
#   'attendance': '37430',
#   'wp': 'bauet001',
#   'lp': 'fistd001',
#   'save': None},
#  {'id': 'BOS201708150',
#   'visteam': 'SLN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/15',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'carav901',
#   'ump1b': 'segac901',
#   'ump2b': 'rippm901',
#   'ump3b': 'hallt901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '74',
#   'winddir': 'tolf',
#   'windspeed': '11',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '172',
#   'attendance': '37345',
#   'wp': 'porcr001',
#   'lp': 'leakm001',
#   'save': None},
#  {'id': 'BOS201708160',
#   'visteam': 'SLN',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/16',
#   'number': '0',
#   'starttime': '7:12PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'segac901',
#   'ump1b': 'rippm901',
#   'ump2b': 'hallt901',
#   'ump3b': 'carav901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '81',
#   'winddir': 'ltor',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'overcast',
#   'timeofgame': '215',
#   'attendance': '37181',
#   'wp': 'kimbc001',
#   'lp': 'dukez001',
#   'save': None},
#  {'id': 'BOS201708180',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/18',
#   'number': '0',
#   'starttime': '7:12PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'iassd901',
#   'ump1b': 'gibsh902',
#   'ump2b': 'barkl901',
#   'ump3b': 'coope901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '75',
#   'winddir': 'tolf',
#   'windspeed': '14',
#   'fieldcond': 'wet',
#   'precip': 'rain',
#   'sky': 'unknown',
#   'timeofgame': '249',
#   'attendance': '36784',
#   'wp': 'reeda001',
#   'lp': 'kahnt001',
#   'save': 'kimbc001'},
#  {'id': 'BOS201708190',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/19',
#   'number': '0',
#   'starttime': '7:12PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'gibsh902',
#   'ump1b': 'barkl901',
#   'ump2b': 'coope901',
#   'ump3b': 'iassd901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '66',
#   'winddir': 'fromcf',
#   'windspeed': '5',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '189',
#   'attendance': '37274',
#   'wp': 'sabac001',
#   'lp': 'salec001',
#   'save': 'betad001'},
#  {'id': 'BOS201708200',
#   'visteam': 'NYA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/20',
#   'number': '0',
#   'starttime': '1:43PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'barkl901',
#   'ump1b': 'iassd901',
#   'ump2b': 'lives901',
#   'ump3b': 'gibsh902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '81',
#   'winddir': 'ltor',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '216',
#   'attendance': '36911',
#   'wp': 'porcr001',
#   'lp': 'grays001',
#   'save': None},
#  {'id': 'BOS201708250',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/25',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'barrs901',
#   'ump1b': 'wolcq901',
#   'ump2b': 'onorb901',
#   'ump3b': 'emmep901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '69',
#   'winddir': 'fromcf',
#   'windspeed': '6',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '217',
#   'attendance': '37191',
#   'wp': 'hellj001',
#   'lp': 'porcr001',
#   'save': None},
#  {'id': 'BOS201708260',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/26',
#   'number': '0',
#   'starttime': '4:08PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'wolcq901',
#   'ump1b': 'onorb901',
#   'ump2b': 'emmep901',
#   'ump3b': 'barrs901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '73',
#   'winddir': 'rtol',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '178',
#   'attendance': '36655',
#   'wp': 'gausk001',
#   'lp': 'rodre004',
#   'save': None},
#  {'id': 'BOS201708270',
#   'visteam': 'BAL',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/08/27',
#   'number': '0',
#   'starttime': '1:35PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'onorb901',
#   'ump1b': 'emmep901',
#   'ump2b': 'barrs901',
#   'ump3b': 'wolcq901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '71',
#   'winddir': 'fromrf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '202',
#   'attendance': '36625',
#   'wp': 'milew001',
#   'lp': 'fistd001',
#   'save': 'bracb001'},
#  {'id': 'BOS201709040',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/04',
#   'number': '0',
#   'starttime': '7:12PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'belld901',
#   'ump1b': 'hudsm901',
#   'ump2b': 'lives901',
#   'ump3b': 'laynj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '73',
#   'winddir': 'tolf',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '205',
#   'attendance': '34311',
#   'wp': 'happj001',
#   'lp': 'porcr001',
#   'save': None},
#  {'id': 'BOS201709050',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/05',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'hudsm901',
#   'ump1b': 'lives901',
#   'ump2b': 'laynj901',
#   'ump3b': 'belld901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '79',
#   'winddir': 'tolf',
#   'windspeed': '17',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '360',
#   'attendance': '33009',
#   'wp': 'velah001',
#   'lp': 'rowlc001',
#   'save': None},
#  {'id': 'BOS201709060',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/06',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'lives901',
#   'ump1b': 'laynj901',
#   'ump2b': 'belld901',
#   'ump3b': 'hudsm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '65',
#   'winddir': 'fromrf',
#   'windspeed': '6',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '177',
#   'attendance': '33190',
#   'wp': 'fistd001',
#   'lp': 'biagj001',
#   'save': None},
#  {'id': 'BOS201709080',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/08',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'barrs901',
#   'ump1b': 'wolcq901',
#   'ump2b': 'onorb901',
#   'ump3b': 'emmep901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '70',
#   'winddir': 'ltor',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '194',
#   'attendance': '34781',
#   'wp': 'pomed001',
#   'lp': 'archc001',
#   'save': None},
#  {'id': 'BOS201709090',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/09',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'wolcq901',
#   'ump1b': 'onorb901',
#   'ump2b': 'emmep901',
#   'ump3b': 'barrs901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '63',
#   'winddir': 'rtol',
#   'windspeed': '5',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '185',
#   'attendance': '36734',
#   'wp': 'salec001',
#   'lp': 'andrm001',
#   'save': None},
#  {'id': 'BOS201709100',
#   'visteam': 'TBA',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/10',
#   'number': '0',
#   'starttime': '1:36PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'onorb901',
#   'ump1b': 'emmep901',
#   'ump2b': 'barrs901',
#   'ump3b': 'wolcq901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '67',
#   'winddir': 'fromrf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '202',
#   'attendance': '35859',
#   'wp': 'cobba001',
#   'lp': 'porcr001',
#   'save': 'coloa001'},
#  {'id': 'BOS201709120',
#   'visteam': 'OAK',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/12',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'westj901',
#   'ump1b': 'wendh902',
#   'ump2b': 'fleta901',
#   'ump3b': 'porta901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '80',
#   'winddir': 'torf',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '186',
#   'attendance': '34355',
#   'wp': 'rodre004',
#   'lp': 'manas001',
#   'save': None},
#  {'id': 'BOS201709130',
#   'visteam': 'OAK',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/13',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'wendh902',
#   'ump1b': 'fleta901',
#   'ump2b': 'porta901',
#   'ump3b': 'westj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '68',
#   'winddir': 'tolf',
#   'windspeed': '5',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '187',
#   'attendance': '36366',
#   'wp': 'cottj001',
#   'lp': 'fistd001',
#   'save': None},
#  {'id': 'BOS201709140',
#   'visteam': 'OAK',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/14',
#   'number': '0',
#   'starttime': '1:36PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'fleta901',
#   'ump1b': 'porta901',
#   'ump2b': 'westj901',
#   'ump3b': 'wendh902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '81',
#   'winddir': 'tocf',
#   'windspeed': '17',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '199',
#   'attendance': '35470',
#   'wp': 'pomed001',
#   'lp': 'gossd001',
#   'save': None},
#  {'id': 'BOS201709250',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/25',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'fairc901',
#   'ump1b': 'rackd901',
#   'ump2b': 'vanol901',
#   'ump3b': 'marqa901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'ellib701',
#   'temp': '71',
#   'winddir': 'fromrf',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '177',
#   'attendance': '33940',
#   'wp': 'andeb004',
#   'lp': 'pomed001',
#   'save': 'osunr001'},
#  {'id': 'BOS201709260',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/26',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'rackd901',
#   'ump1b': 'vanol901',
#   'ump2b': 'marqa901',
#   'ump3b': 'fairc901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '75',
#   'winddir': 'fromrf',
#   'windspeed': '5',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '184',
#   'attendance': '33999',
#   'wp': 'happj001',
#   'lp': 'salec001',
#   'save': None},
#  {'id': 'BOS201709270',
#   'visteam': 'TOR',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/27',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'vanol901',
#   'ump1b': 'marqa901',
#   'ump2b': 'fairc901',
#   'ump3b': 'rackd901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '82',
#   'winddir': 'tolf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '177',
#   'attendance': '34445',
#   'wp': 'porcr001',
#   'lp': 'estrm001',
#   'save': None},
#  {'id': 'BOS201709280',
#   'visteam': 'HOU',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/28',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'westj901',
#   'ump1b': 'fleta901',
#   'ump2b': 'wendh902',
#   'ump3b': 'porta901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '69',
#   'winddir': 'fromlf',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '211',
#   'attendance': '34222',
#   'wp': 'peacb001',
#   'lp': 'rodre004',
#   'save': None},
#  {'id': 'BOS201709290',
#   'visteam': 'HOU',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/29',
#   'number': '0',
#   'starttime': '7:09PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'fleta901',
#   'ump1b': 'wendh902',
#   'ump2b': 'porta901',
#   'ump3b': 'westj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'scogc701',
#   'temp': '59',
#   'winddir': 'rtol',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '167',
#   'attendance': '36623',
#   'wp': 'mortc002',
#   'lp': 'fistd001',
#   'save': 'gilek001'},
#  {'id': 'BOS201709300',
#   'visteam': 'HOU',
#   'hometeam': 'BOS',
#   'site': 'BOS07',
#   'date': '2017/09/30',
#   'number': '0',
#   'starttime': '1:05PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'wendh902',
#   'ump1b': 'porta901',
#   'ump2b': 'westj901',
#   'ump3b': 'fleta901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'shalm701',
#   'temp': '57',
#   'winddir': 'fromrf',
#   'windspeed': '14',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '199',
#   'attendance': '35722',
#   'wp': 'pomed001',
#   'lp': 'mccul002',
#   'save': None},
#  {'id': 'CHA201704040',
#   'visteam': 'DET',
#   'hometeam': 'CHA',
#   'site': 'CHI12',
#   'date': '2017/04/04',
#   'number': '0',
#   'starttime': '1:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'gormb901',
#   'ump1b': 'iassd901',
#   'ump2b': 'dimum901',
#   'ump3b': 'gibsh902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'roseb701',
#   'temp': '48',
#   'winddir': 'torf',
#   'windspeed': '11',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'overcast',
#   'timeofgame': '210',
#   'attendance': '36534',
#   'wp': 'verlj001',
#   'lp': 'quinj001',
#   'save': 'rodrf003'},
#  {'id': 'CHA201704060',
#   'visteam': 'DET',
#   'hometeam': 'CHA',
#   'site': 'CHI12',
# ...
#   'save': None},
#  {'id': 'DET201705010',
#   'visteam': 'CLE',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/01',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'nauep901',
#   'ump1b': 'guccc901',
#   'ump2b': 'torrc901',
#   'ump3b': 'demud901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '57',
#   'winddir': 'rtol',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '194',
#   'attendance': '22045',
#   'wp': 'norrd002',
#   'lp': 'bauet001',
#   'save': None},
#  {'id': 'DET201705020',
#   'visteam': 'CLE',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/02',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'guccc901',
#   'ump1b': 'torrc901',
#   'ump2b': 'demud901',
#   'ump3b': 'nauep901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '47',
#   'winddir': 'rtol',
#   'windspeed': '21',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '194',
#   'attendance': '21799',
#   'wp': 'verlj001',
#   'lp': 'klubc001',
#   'save': 'rodrf003'},
#  {'id': 'DET201705030',
#   'visteam': 'CLE',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/03',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'torrc901',
#   'ump1b': 'demud901',
#   'ump2b': 'nauep901',
#   'ump3b': 'guccc901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '58',
#   'winddir': 'ltor',
#   'windspeed': '8',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '183',
#   'attendance': '22663',
#   'wp': 'carrc003',
#   'lp': 'boydm001',
#   'save': 'allec002'},
#  {'id': 'DET201705160',
#   'visteam': 'BAL',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/16',
#   'number': '0',
#   'starttime': '7:11PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'culbf901',
#   'ump1b': 'carlm901',
#   'ump2b': 'buckc901',
#   'ump3b': 'gonzm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '84',
#   'winddir': 'rtol',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '319',
#   'attendance': '25109',
#   'wp': 'bleir001',
#   'lp': 'rodrf003',
#   'save': None},
#  {'id': 'DET201705170',
#   'visteam': 'BAL',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/17',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'carlm901',
#   'ump1b': 'buckc901',
#   'ump2b': 'gonzm901',
#   'ump3b': 'culbf901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '83',
#   'winddir': 'rtol',
#   'windspeed': '19',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '195',
#   'attendance': '29722',
#   'wp': 'fulmm001',
#   'lp': 'jimeu001',
#   'save': 'wilsj004'},
#  {'id': 'DET201705180',
#   'visteam': 'BAL',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/18',
#   'number': '0',
#   'starttime': '1:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'buckc901',
#   'ump1b': 'gonzm901',
#   'ump2b': 'culbf901',
#   'ump3b': 'carlm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '83',
#   'winddir': 'rtol',
#   'windspeed': '21',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '173',
#   'attendance': '32455',
#   'wp': 'zimmj003',
#   'lp': 'bundd001',
#   'save': 'wilsa001'},
#  {'id': 'DET201705190',
#   'visteam': 'TEX',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/19',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'drecb901',
#   'ump1b': 'everm901',
#   'ump2b': 'bakej902',
#   'ump3b': 'welkb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'kleir701',
#   'temp': '52',
#   'winddir': 'ltor',
#   'windspeed': '13',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '203',
#   'attendance': '33122',
#   'wp': 'martn002',
#   'lp': 'norrd002',
#   'save': 'bushm001'},
#  {'id': 'DET201705200',
#   'visteam': 'TEX',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/20',
#   'number': '0',
#   'starttime': '7:16PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'everm901',
#   'ump1b': 'bakej902',
#   'ump2b': 'welkb901',
#   'ump3b': 'drecb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '56',
#   'winddir': 'fromlf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'overcast',
#   'timeofgame': '178',
#   'attendance': '35166',
#   'wp': 'verlj001',
#   'lp': 'grifa002',
#   'save': None},
#  {'id': 'DET201705210',
#   'visteam': 'TEX',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/05/21',
#   'number': '0',
#   'starttime': '8:09PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'bakej902',
#   'ump1b': 'welkb901',
#   'ump2b': 'drecb901',
#   'ump3b': 'everm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '73',
#   'winddir': 'rtol',
#   'windspeed': '14',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '215',
#   'attendance': '24080',
#   'wp': 'darvy001',
#   'lp': 'boydm001',
#   'save': 'kelak001'},
#  {'id': 'DET201706020',
#   'visteam': 'CHA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/02',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'carlm901',
#   'ump1b': 'buckc901',
#   'ump2b': 'gonzm901',
#   'ump3b': 'culbf901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'kleir701',
#   'temp': '79',
#   'winddir': 'tolf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '181',
#   'attendance': '28619',
#   'wp': 'fulmm001',
#   'lp': 'holld003',
#   'save': None},
#  {'id': 'DET201706030',
#   'visteam': 'CHA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/03',
#   'number': '0',
#   'starttime': '4:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'gonzm901',
#   'ump1b': 'culbf901',
#   'ump2b': 'whitc901',
#   'ump3b': 'carlm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '76',
#   'winddir': 'rtol',
#   'windspeed': '4',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '194',
#   'attendance': '33188',
#   'wp': 'zimmj003',
#   'lp': 'gonzm003',
#   'save': None},
#  {'id': 'DET201706040',
#   'visteam': 'CHA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/04',
#   'number': '0',
#   'starttime': '1:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'culbf901',
#   'ump1b': 'whitc901',
#   'ump2b': 'carlm901',
#   'ump3b': 'gonzm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '74',
#   'winddir': 'rtol',
#   'windspeed': '3',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '247',
#   'attendance': '30208',
#   'wp': 'wilsj004',
#   'lp': 'robed002',
#   'save': None},
#  {'id': 'DET201706060',
#   'visteam': 'ANA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/06',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'fleta901',
#   'ump1b': 'porta901',
#   'ump2b': 'westj901',
#   'ump3b': 'wendh902',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '62',
#   'winddir': 'ltor',
#   'windspeed': '15',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '194',
#   'attendance': '24175',
#   'wp': 'chavj001',
#   'lp': 'norrd002',
#   'save': 'norrb001'},
#  {'id': 'DET201706070',
#   'visteam': 'ANA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/07',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'porta901',
#   'ump1b': 'westj901',
#   'ump2b': 'wendh902',
#   'ump3b': 'fleta901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '72',
#   'winddir': 'rtol',
#   'windspeed': '11',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '178',
#   'attendance': '24958',
#   'wp': 'farmb001',
#   'lp': 'meyea001',
#   'save': None},
#  {'id': 'DET201706080',
#   'visteam': 'ANA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/08',
#   'number': '0',
#   'starttime': '1:11PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'westj901',
#   'ump1b': 'wendh902',
#   'ump2b': 'fleta901',
#   'ump3b': 'porta901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '72',
#   'winddir': 'ltor',
#   'windspeed': '2',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '204',
#   'attendance': '34810',
#   'wp': 'ramij002',
#   'lp': 'fulmm001',
#   'save': None},
#  {'id': 'DET201706130',
#   'visteam': 'ARI',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/13',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'laynj901',
#   'ump1b': 'woodt901',
#   'ump2b': 'estam901',
#   'ump3b': 'hudsm901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '84',
#   'winddir': 'ltor',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '228',
#   'attendance': '25119',
#   'wp': 'brada001',
#   'lp': 'wilsj004',
#   'save': 'rodnf001'},
#  {'id': 'DET201706140',
#   'visteam': 'ARI',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/14',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'woodt901',
#   'ump1b': 'estam901',
#   'ump2b': 'hudsm901',
#   'ump3b': 'laynj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '82',
#   'winddir': 'ltor',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '165',
#   'attendance': '26134',
#   'wp': 'walkt004',
#   'lp': 'zimmj003',
#   'save': 'rodnf001'},
#  {'id': 'DET201706150',
#   'visteam': 'TBA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/15',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'may-b901',
#   'ump1b': 'hicke901',
#   'ump2b': 'mealj901',
#   'ump3b': 'conrc901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '83',
#   'winddir': 'rtol',
#   'windspeed': '9',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '209',
#   'attendance': '24056',
#   'wp': 'wilsj004',
#   'lp': 'huntt002',
#   'save': None},
#  {'id': 'DET201706160',
#   'visteam': 'TBA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/16',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'hicke901',
#   'ump1b': 'mealj901',
#   'ump2b': 'conrc901',
#   'ump3b': 'may-b901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'kleir701',
#   'temp': '81',
#   'winddir': 'rtol',
#   'windspeed': '7',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '185',
#   'attendance': '29674',
#   'wp': 'norrd002',
#   'lp': 'ramie004',
#   'save': None},
#  {'id': 'DET201706170',
#   'visteam': 'TBA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/17',
#   'number': '0',
#   'starttime': '4:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'mealj901',
#   'ump1b': 'conrc901',
#   'ump2b': 'may-b901',
#   'ump3b': 'hicke901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'kleir701',
#   'temp': '85',
#   'winddir': 'rtol',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '203',
#   'attendance': '33478',
#   'wp': 'archc001',
#   'lp': 'fulmm001',
#   'save': 'coloa001'},
#  {'id': 'DET201706180',
#   'visteam': 'TBA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/18',
#   'number': '0',
#   'starttime': '1:41PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'conrc901',
#   'ump1b': 'may-b901',
#   'ump2b': 'hicke901',
#   'ump3b': 'mealj901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '78',
#   'winddir': 'rtol',
#   'windspeed': '17',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '185',
#   'attendance': '36442',
#   'wp': 'farij001',
#   'lp': 'farmb001',
#   'save': None},
#  {'id': 'DET201706270',
#   'visteam': 'KCA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/27',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'belld901',
#   'ump1b': 'lentn901',
#   'ump2b': 'iassd901',
#   'ump3b': 'gormb901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '72',
#   'winddir': 'rtol',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '194',
#   'attendance': '29488',
#   'wp': 'verlj001',
#   'lp': 'stram001',
#   'save': 'wilsj004'},
#  {'id': 'DET201706280',
#   'visteam': 'KCA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/28',
#   'number': '0',
#   'starttime': '7:10PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'lentn901',
#   'ump1b': 'iassd901',
#   'ump2b': 'gormb901',
#   'ump3b': 'belld901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '74',
#   'winddir': 'rtol',
#   'windspeed': '14',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'overcast',
#   'timeofgame': '166',
#   'attendance': '29614',
#   'wp': 'kenni001',
#   'lp': 'norrd002',
#   'save': None},
#  {'id': 'DET201706290',
#   'visteam': 'KCA',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/06/29',
#   'number': '0',
#   'starttime': '1:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'iassd901',
#   'ump1b': 'gormb901',
#   'ump2b': 'belld901',
#   'ump3b': 'lentn901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'klonc701',
#   'temp': '78',
#   'winddir': 'rtol',
#   'windspeed': '16',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'unknown',
#   'timeofgame': '153',
#   'attendance': '33681',
#   'wp': 'fulmm001',
#   'lp': 'junij001',
#   'save': None},
#  {'id': 'DET201707011',
#   'visteam': 'CLE',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/07/01',
#   'number': '1',
#   'starttime': '1:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'kellj901',
#   'ump1b': 'blakr901',
#   'ump2b': 'hoyej901',
#   'ump3b': 'littw901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '78',
#   'winddir': 'rtol',
#   'windspeed': '11',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '179',
#   'attendance': '28719',
#   'wp': 'grees005',
#   'lp': 'shawb001',
#   'save': 'wilsj004'},
#  {'id': 'DET201707012',
#   'visteam': 'CLE',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/07/01',
#   'number': '2',
#   'starttime': '7:16PM',
#   'daynight': 'night',
#   'usedh': 'true',
#   'umphome': 'timmt901',
#   'ump1b': 'hoyej901',
#   'ump2b': 'littw901',
#   'ump3b': 'blakr901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '81',
#   'winddir': 'tolf',
#   'windspeed': '12',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'cloudy',
#   'timeofgame': '197',
#   'attendance': '27016',
#   'wp': 'carrc003',
#   'lp': 'zimmj003',
#   'save': 'milla002'},
#  {'id': 'DET201707020',
#   'visteam': 'CLE',
#   'hometeam': 'DET',
#   'site': 'DET05',
#   'date': '2017/07/02',
#   'number': '0',
#   'starttime': '1:10PM',
#   'daynight': 'day',
#   'usedh': 'true',
#   'umphome': 'hoyej901',
#   'ump1b': 'littw901',
#   'ump2b': 'kellj901',
#   'ump3b': 'timmt901',
#   'howscored': 'park',
#   'pitches': 'pitches',
#   'oscorer': 'marod701',
#   'temp': '79',
#   'winddir': 'tolf',
#   'windspeed': '10',
#   'fieldcond': 'unknown',
#   'precip': 'unknown',
#   'sky': 'sunny',
#   'timeofgame': '235',
#   'attendance': '30429',
#   'wp': 'clevm001',
#   'lp': 'verlj001',
#   'save': 'allec002'},
#  ...]

# %% [markdown]
# With 30 teams and 162 regular season games (each of which, of course, involves 2 teams!), the above list should contain info for 30 * 162 / 2 = 2430 games.

# %%
len(data)
# Out:
# 2400

# %% [markdown]
# Seems we're missing 30 games, but we'll figure that out later.
#
# In this format, in any case, we can easily create a DataFrame.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame.from_records(data)
df
# Out:
#                 id visteam hometeam   site        date number starttime  \
# 0     BOS201704030     PIT      BOS  BOS07  2017/04/03      0    2:06PM
# 1     BOS201704050     PIT      BOS  BOS07  2017/04/05      0    7:10PM
# 2     BOS201704110     BAL      BOS  BOS07  2017/04/11      0    7:10PM
# 3     BOS201704120     BAL      BOS  BOS07  2017/04/12      0    7:10PM
# 4     BOS201704130     PIT      BOS  BOS07  2017/04/13      0    2:06PM
# ...            ...     ...      ...    ...         ...    ...       ...
# 2395  CHN201709150     SLN      CHN  CHI11  2017/09/15      0    1:21PM
# 2396  CHN201709160     SLN      CHN  CHI11  2017/09/16      0    3:05PM
# 2397  CHN201709170     SLN      CHN  CHI11  2017/09/17      0    1:23PM
# 2398  CHN201709290     CIN      CHN  CHI11  2017/09/29      0    1:22PM
# 2399  CHN201709300     CIN      CHN  CHI11  2017/09/30      0    3:05PM
#
#      daynight  usedh   umphome  ...  winddir windspeed fieldcond   precip  \
# 0         day   true  demud901  ...   fromrf        13   unknown  unknown
# 1       night   true  nauep901  ...   fromrf         8   unknown  unknown
# 2       night   true  coope901  ...     tolf        16   unknown  unknown
# 3       night   true  johna901  ...     rtol         6   unknown  unknown
# 4         day   true  morag901  ...     torf        15   unknown  unknown
# ...       ...    ...       ...  ...      ...       ...       ...      ...
# 2395      day  false  bakej902  ...     rtol        11   unknown  unknown
# 2396      day  false  torrc901  ...     rtol        11   unknown  unknown
# 2397      day  false  drecb901  ...   fromrf         5   unknown  unknown
# 2398      day  false  muchm901  ...  unknown        15   unknown  unknown
# 2399      day  false  wintm901  ...   fromrf        11   unknown  unknown
#
#           sky timeofgame attendance        wp        lp      save
# 0      cloudy        183      36594  porcr001  coleg001  kimbc001
# 1     unknown        233      36137  kellj001  basta001      None
# 2     unknown        195      37497  pomed001  bundd001      None
# 3     unknown        226      32211  givem001  wrigs001      None
# 4      cloudy        195      32400  barnm001  nicaj001  kimbc001
# ...       ...        ...        ...       ...       ...       ...
# 2395    sunny        187      38464  edwac001  martc006      None
# 2396    sunny        169      40959  hendk001  wachm001  daviw001
# 2397  unknown        224      37242  strop001  lyont001  daviw001
# 2398    sunny        176      36258  duenb001  lorem002  grimj002
# 2399    sunny        184      41493  lestj001  stepj002      None
#
# [2400 rows x 27 columns]

# %% [markdown]
# In this format, we can actually make some sense of all this information!
#
# For example, in 2017, which ballparks had the highest average attendance?

# %%
df['attendance'] = df['attendance'].astype('int')

avg_attendance = df.groupby('site')['attendance'].mean().sort_values(ascending=False)

avg_attendance
# Out:
# site
# LOS03    46482.287500
# STL10    42544.375000
# SFO03    40810.062500
# CHI11    39482.387500
# TOR02    39456.150000
# NYC21    39383.600000
# ANA01    37308.062500
# DEN02    36508.800000
# BOS07    36039.512500
# MIL06    31294.120482
# WAS11    31116.600000
# ARL02    30922.487500
# ATL03    30900.862500
# HOU03    30570.415584
# NYC20    29897.771084
# DET05    28721.462500
# KAN06    27351.162500
# PHO01    26429.087500
# SEA03    26396.875000
# SAN02    26376.900000
# MIN04    25289.137500
# CLE08    25226.275000
# BAL12    25062.500000
# PIT08    23950.278481
# PHI13    23495.000000
# CIN09    22642.150000
# MIA02    20231.064935
# CHI12    20123.425000
# OAK01    18282.362500
# STP01    15013.550000
# WIL02     2596.000000
# Name: attendance, dtype: float64

# %% [markdown]
# We can make this a little more legible by joining with a table containing the ballpark names that match the codes"

# %%
ballparks = pd.read_csv('../data/retrosheet/parkcodes.csv')
ballparks
# Out:
#     PARKID                                 NAME  \
# 0    ALB01                       Riverside Park
# 1    ALT01                        Columbia Park
# 2    ANA01             Angel Stadium of Anaheim
# 3    ARL01                    Arlington Stadium
# 4    ARL02        Rangers Ballpark in Arlington
# ..     ...                                  ...
# 255  WIL02        BB&T Ballpark at Bowman Field
# 256  WNY01     West New York Field Club Grounds
# 257  WOR01   Agricultural County Fair Grounds I
# 258  WOR02  Agricultural County Fair Grounds II
# 259  WOR03       Worcester Driving Park Grounds
#
#                                           AKA           CITY STATE  \
# 0                                         NaN         Albany    NY
# 1                                         NaN        Altoona    PA
# 2               Edison Field; Anaheim Stadium        Anaheim    CA
# 3                                         NaN      Arlington    TX
# 4    The Ballpark in Arlington; Ameriquest Fl      Arlington    TX
# ..                                        ...            ...   ...
# 255                                       NaN   Williamsport    PA
# 256                                       NaN  West New York    NJ
# 257                                       NaN      Worcester    MA
# 258                                       NaN      Worcester    MA
# 259                                       NaN      Worcester    MA
#
#           START         END LEAGUE  \
# 0    09/11/1880  05/30/1882     NL
# 1    04/30/1884  05/31/1884     UA
# 2    04/19/1966         NaN     AL
# 3    04/21/1972  10/03/1993     AL
# 4    04/11/1994  09/29/2019     AL
# ..          ...         ...    ...
# 255  08/20/2017  08/20/2017     NL
# 256  09/11/1898  09/17/1899     NL
# 257  05/01/1880  09/29/1882     NL
# 258  08/17/1887  08/17/1887     NL
# 259  10/30/1874  10/30/1874    NaN
#
#                                                  NOTES
# 0       TRN:9/11/80;6/15&9/10/1881;5/16-5/18&5/30/1882
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 255                                                PIT
# 256  BRO:9/18&10/2/1898; NY1:9/11/98, 6/4&7/16&8/13...
# 257                                                NaN
# 258                                         1 BSN game
# 259                                         1 BS1 game
#
# [260 rows x 9 columns]

# %%
pd.merge(left=avg_attendance, right=ballparks, how='left', left_on='site', right_on='PARKID')
# Out:
#       attendance PARKID                                       NAME  \
# 0   46482.287500  LOS03                             Dodger Stadium
# 1   42544.375000  STL10                          Busch Stadium III
# 2   40810.062500  SFO03                                  AT&T Park
# 3   39482.387500  CHI11                              Wrigley Field
# 4   39456.150000  TOR02                              Rogers Centre
# 5   39383.600000  NYC21                          Yankee Stadium II
# 6   37308.062500  ANA01                   Angel Stadium of Anaheim
# 7   36508.800000  DEN02                                Coors Field
# 8   36039.512500  BOS07                                Fenway Park
# 9   31294.120482  MIL06                                Miller Park
# 10  31116.600000  WAS11                             Nationals Park
# 11  30922.487500  ARL02              Rangers Ballpark in Arlington
# 12  30900.862500  ATL03                              Suntrust Park
# 13  30570.415584  HOU03                           Minute Maid Park
# 14  29897.771084  NYC20                                 Citi Field
# 15  28721.462500  DET05                              Comerica Park
# 16  27351.162500  KAN06                           Kauffman Stadium
# 17  26429.087500  PHO01                                Chase Field
# 18  26396.875000  SEA03                               Safeco Field
# 19  26376.900000  SAN02                                 PETCO Park
# 20  25289.137500  MIN04                               Target Field
# 21  25226.275000  CLE08                          Progressive Field
# 22  25062.500000  BAL12                Oriole Park at Camden Yards
# 23  23950.278481  PIT08                                   PNC Park
# 24  23495.000000  PHI13                         Citizens Bank Park
# 25  22642.150000  CIN09                    Great American Ballpark
# 26  20231.064935  MIA02                               Marlins Park
# 27  20123.425000  CHI12  Guaranteed Rate Field;U.S. Cellular Field
# 28  18282.362500  OAK01            Oakland-Alameda County Coliseum
# 29  15013.550000  STP01                            Tropicana Field
# 30   2596.000000  WIL02              BB&T Ballpark at Bowman Field
#
#                                          AKA            CITY STATE  \
# 0                              Chavez Ravine     Los Angeles    CA
# 1                                        NaN       St. Louis    MO
# 2                Pacific Bell Park; SBC Park   San Francisco    CA
# 3                   Weeghman Park; Cubs Park         Chicago    IL
# 4                                    Skydome         Toronto   ONT
# 5                                        NaN        New York    NY
# 6              Edison Field; Anaheim Stadium         Anaheim    CA
# 7                                        NaN          Denver    CO
# 8                                        NaN          Boston    MA
# 9                                        NaN       Milwaukee    WI
# 10                                       NaN      Washington    DC
# 11  The Ballpark in Arlington; Ameriquest Fl       Arlington    TX
# 12                                       NaN         Atlanta    GA
# 13                 Enron Field; Astros Field         Houston    TX
# 14                                       NaN        New York    NY
# 15                                       NaN         Detroit    MI
# 16                            Royals Stadium     Kansas City    MO
# 17                         Bank One Ballpark         Phoenix    AZ
# 18                                       NaN         Seattle    WA
# 19                                       NaN       San Diego    CA
# 20                                       NaN     Minneapolis    MN
# 21                              Jacobs Field       Cleveland    OH
# 22                                       NaN       Baltimore    MD
# 23                                       NaN      Pittsburgh    PA
# 24                                       NaN    Philadelphia    PA
# 25                                       NaN      Cincinnati    OH
# 26                                       NaN           Miami    FL
# 27          White Sox Park; Comiskey Park II         Chicago    IL
# 28               Network Associates Coliseum         Oakland    CA
# 29                                       NaN  St. Petersburg    FL
# 30                                       NaN    Williamsport    PA
#
#          START         END LEAGUE  \
# 0   04/10/1962         NaN     NL
# 1   04/10/2006         NaN     NL
# 2   04/11/2000         NaN     NL
# 3   04/23/1914         NaN     NL
# 4   06/05/1989         NaN     AL
# 5   04/16/2009         NaN     AL
# 6   04/19/1966         NaN     AL
# 7   04/26/1995         NaN     NL
# 8   04/20/1912         NaN     AL
# 9   04/06/2001         NaN     NL
# 10  03/30/2008         NaN     NL
# 11  04/11/1994  09/29/2019     AL
# 12  04/14/2017         NaN     NL
# 13  04/07/2000         NaN     NL
# 14  04/13/2009         NaN     NL
# 15  04/11/2000         NaN     AL
# 16  04/10/1973         NaN     AL
# 17  03/31/1998         NaN     NL
# 18  07/15/1999         NaN     AL
# 19  04/08/2004         NaN     NL
# 20  04/12/2010         NaN     AL
# 21  04/04/1994         NaN     AL
# 22  04/06/1992         NaN     AL
# 23  04/09/2001         NaN     NL
# 24  04/12/2004         NaN     NL
# 25  03/31/2003         NaN     NL
# 26  04/04/2012         NaN     NL
# 27  04/18/1991         NaN     AL
# 28  04/17/1968         NaN     AL
# 29  03/31/1998         NaN     AL
# 30  08/20/2017  08/20/2017     NL
#
#                                                 NOTES
# 0   LAN:1962-prsnt; LAA:1962-9/2/65; CAL:9/2to9/22/65
# 1                                                 NaN
# 2                                                 NaN
# 3                          CHF:1914-15; CHN:1916-date
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8     BOS:1912-date; BSN:9/7to9/29/1914;4/14to7/26/15
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                PIT

# %% [markdown]
# There you have it! In 2017, Dodger Stadium (go Dodgers!) had the highest average attendence at 46,482, followed by the Cardinals' Busch Stadium, the Giants' AT&T Park, and the Cubs' Wrigley Field.
#
# Maybe we'll also want to have a look at things like weather and wind conditions, game duration, etc. On their own these might be fun to look at, but once the rest of the Retrosheet event file is parsed, we could have some potentially powerful insights on our hands about how game conditions correlate with game stats.
